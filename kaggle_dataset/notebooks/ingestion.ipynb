# %%
import os
import sys

# Move working directory to kaggle_dataset/
PROJECT_ROOT = os.path.abspath("..")
os.chdir(PROJECT_ROOT)



print("Working directory:", os.getcwd())
# Out:
# Working directory: d:\projects\CreditPathAI_Oct_Batch\kaggle_dataset

# %%
from src.ingestion import CSVIngestion

raw_path = "D:/projects/CreditPathAI_Oct_Batch/kaggle_dataset/data/01_raw/Kaggle_loan_default.csv"
interim_path = "D:/projects/CreditPathAI_Oct_Batch/kaggle_dataset/data/02_interim/loan_data_clean.csv"

# %%
ingestion = CSVIngestion(
    input_path=raw_path,
    output_path=interim_path
)

df = ingestion.run()
df.head()
# Out:
#    Unnamed: 0      id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           2       2          2        0.0          0.0              0.0
# 1           3  545583     703644     2500.0       2500.0           2500.0
# 2           4  532101     687836     5000.0       5000.0           5000.0
# 3           5  877788    1092507     7000.0       7000.0           7000.0
# 4           6  875406    1089981     2000.0       2000.0           2000.0
#
#         term  int_rate  installment emp_length  ... total_acc  total_pymnt  \
# 0  36 months      0.00         0.00   < 1 year  ...       1.0     0.000000
# 1  36 months     13.98        85.42    4 years  ...      10.0  3075.291779
# 2  36 months     15.95       175.67    4 years  ...      15.0  2948.760000
# 3  36 months      9.91       225.58  10+ years  ...      20.0  8082.391880
# 4  36 months      5.42        60.32  10+ years  ...      15.0  2161.663244
#
# ...

# %%
print("Final shape:", df.shape)
print("Duplicates:", df.duplicated().sum())
print("Missing values:\n", df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Final shape: (38480, 37)
# Duplicates: 0
# Missing values:
#  loan_amnt                     1
# funded_amnt                   1
# funded_amnt_inv               1
# installment                   1
# emp_length                  993
# annual_inc                    2
# delinq_2yrs                   1
# inq_last_6mths                1
# mths_since_last_delinq    24363
# open_acc                      1
# pub_rec                       1
# revol_bal                     4
# revol_util                   59
# total_acc                     1
# total_pymnt                   1
# total_pymnt_inv               1
# total_rec_prncp               1
# total_rec_int                 1
# last_pymnt_d                 71
# last_pymnt_amnt               1
# next_pymnt_d              35097
# last_credit_pull_d            3
# dtype: int64
